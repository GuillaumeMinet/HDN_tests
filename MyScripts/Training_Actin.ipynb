# %%
import warnings
warnings.filterwarnings('ignore')
# We import all our dependencies.
import numpy as np
import torch
import sys
sys.path.append('../')
from models.lvae import LadderVAE
from lib.gaussianMixtureNoiseModel import GaussianMixtureNoiseModel
from boilerplate import boilerplate
import lib.utils as utils
from lib import histNoiseModel
from lib.utils import plotProbabilityDistribution
import training
from tifffile import imread
from matplotlib import pyplot as plt
from tqdm import tqdm
import os
from pathlib import Path

from pystackreg import StackReg
from skimage.transform import warp,AffineTransform

use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print("Device: ", device)
# Out:
# Device:  cuda

# %%
def crop_center(img,crop_size):

    if type(crop_size) == tuple:
        crop_x,crop_y = crop_size
    elif type(crop_size) == int:
        crop_x = crop_size
        crop_y = crop_size
    
    y,x = img.shape[-2::]
    startx = x//2-(crop_x//2)
    starty = y//2-(crop_y//2)        

    return img[...,starty:starty+crop_y,startx:startx+crop_x]

# %%
#### ALL PARAMETERS DEFINED HERE ####

supervised = True
augment = False

# Data paths
data_path = Path(r"E:\dl_monalisa\Data\Actin_fixed_mltplSNR_30nm_2\dump")
noiseModelsDir = Path(r"E:\dl_monalisa\Data\Actin_fixed_mltplSNR_30nm_2\noise_models\final")

# Choose parameters
upsamp = 1
DataNoiseLvl = "all" # "all",list of int, or int
GMMNoiseLvl = "same"
bootstrapped = False
GMMsig = "avg" # "n2v" or "avg", used for not bootstrapped models only
normSignalToObs = True # put True if signal was normalized to observations when creating GMM
normGMM = True # put True if data was normalized to create the GMM

checkNoiseModelDisplay = True

clean = "avg" # "n2v" or "avg", used for supervised
display = True # display images or not
clip = -3 # False or clip value
registration = False

# Get noise model name
if GMMNoiseLvl == "same":
    GMMNoiseLvl = DataNoiseLvl
if isinstance(GMMNoiseLvl,list):
    GMMNoiseLvlstr = ''.join(str(GMMNoiseLvl).split(', '))[1:-1]
else:
    GMMNoiseLvlstr = GMMNoiseLvl

if bootstrapped:
    GMMname = f"GMM_Noise{GMMNoiseLvlstr}_bootstrapped_Clip{clip}"
else:
    GMMname = f"GMM_Noise{GMMNoiseLvlstr}_Sig{GMMsig.upper()}_Clip{clip}"

if normGMM:
    GMMname = f"{GMMname}_norm.npz"
else:
    GMMname = f"{GMMname}.npz"
print ("Noise model: ", GMMname)
assert os.path.exists(noiseModelsDir/GMMname)

# Load GMM
noise_model_params= np.load(str(noiseModelsDir / GMMname))
# noise_model_params = np.load(r"E:\dl_monalisa\Data\Vim_fixed_mltplSNR_30nm\noise_models\final\GMM_Noise1234_SigN2V_Clip-3.npz")
noiseModel = GaussianMixtureNoiseModel(params = noise_model_params, device = device)

print(f"Upsamp: {upsamp}")
print(f"Supervised: {supervised}")
print(f"Noise level: {DataNoiseLvl}")
print(f"GMM noise level: {GMMNoiseLvl}")
print(f"Clean: {clean}")
print(f"GMM: {GMMname}")

# Training prm
patch_size = 64
gaussian_noise_std = None

# Training-specific
beta = 0.005 # loss = recon_loss + beta * kl_loss
batch_size=64
virtual_batch = 8
lr=5e-6
max_epochs = 500
steps_per_epoch=400
test_batch_size=10

# Model-specific
num_latents = 5
z_dims = [64]*int(num_latents)
blocks_per_layer = 8
batchnorm = True
free_bits = 1.0

# Model name for saving
if isinstance(DataNoiseLvl,list):
    DataNoiseLvlstr = ''.join(str(DataNoiseLvl).split(', '))[1:-1]
else:
    DataNoiseLvlstr = DataNoiseLvl
data_name = str(data_path).split("\\")[3]
if bootstrapped:
    sig = "boostrapped"
else:
    sig = GMMsig.upper()
modelName = f"{data_name}_Noise{DataNoiseLvlstr}_GMM{GMMNoiseLvl}_Clip{clip}_{num_latents}Lat_{blocks_per_layer}Blocks_betaKL{beta}"
if supervised:
    modelName = modelName + f"_Supervised{clean.upper()}"
if upsamp > 1:
    modelName = modelName + "_upsamp2random"
if not augment:
    modelName = modelName + "_NoAugment"

save_model_basedir = "./Trained_model/" 
print(f"Trained model will be saved at: {save_model_basedir}")
print(f"Model save name: {modelName}")
# Out:
# Noise model:  GMM_Noiseall_SigAVG_Clip-3_norm.npz
# Upsamp: 1
# Supervised: True
# Noise level: all
# GMM noise level: all
# Clean: avg
# GMM: GMM_Noiseall_SigAVG_Clip-3_norm.npz
# Trained model will be saved at: ./Trained_model/
# Model save name: Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment

# %%
##### Load data ####
crop_size = (1392,1392)
signal = []
observation = []
filters = ['tif','tiff']

files = os.listdir(data_path)

for f in files:
    if f.split('.')[-1] not in filters:
        print(f"removing {f} in signals because not in filters")
        files.remove(f)

for f in files:
    if f.split('.')[-1] not in filters:
        print(f"Removing {f} in observations because not in filters")
        files.remove(f)

print(f"\nFound {len(files)} files.\n")

if isinstance(DataNoiseLvl,list) or DataNoiseLvl == "all":
    mltplNoise = True
else:
    mltplNoise = False
# Out:
# removing info.txt in signals because not in filters
# removing Thumbs.db in signals because not in filters
# Removing selected_data in observations because not in filters
#
# Found 39 files.

# %%
for f in (files):

    # n2v or avg signal selection
    if clean == "avg":
        im_signal = np.mean(imread(data_path / f)[0:5],axis=0)
    else:
        raise ValueError("avg gt is the only one available for now for actin")
    
    # noise level selection
    if DataNoiseLvl == "all":
        im_obs  = imread(data_path / f)
    elif isinstance(DataNoiseLvl,int) or isinstance(DataNoiseLvl,list):
        im_obs = imread(data_path / f)[DataNoiseLvl]

    if not isinstance(clip,bool):
        im_obs[im_obs<clip] = 0
        im_signal[im_signal<clip] = 0

    if registration:
        if DataNoiseLvl == "all":
            print("Registration not available for all noise level yet")
        else:
            tf = StackReg.TRANSLATION
            sr = StackReg(tf)
            tmat = sr.register(ref=im_signal,mov=im_obs)
            tform = AffineTransform(matrix=tmat)
            im_obs = warp(im_obs, tform,order=0)

    im_obs = crop_center(im_obs,crop_size)
    im_signal = crop_center(im_signal,crop_size)
    
    observation.append(im_obs)
    signal.append(im_signal)

    print(f"File {f}: shape: {im_obs.shape}")

full_signal = []
full_obs = []
if mltplNoise:
    for i,obs in enumerate(observation):
        sig = signal[i]
        if normSignalToObs:
            sig = (sig - np.mean(sig))/np.std(sig)
        for frame in obs:
            if normSignalToObs:
                norm_sig = sig * np.std(frame) + np.mean(frame)
                full_signal.append(norm_sig)
            else:
                full_signal.append(sig)

            full_obs.append(frame)
    observation = np.stack(full_obs)
    signal = np.stack(full_signal)
else:
    observation = np.stack(observation)
    signal = np.stack(signal)


if signal.shape[-1] != signal.shape[-2]:
    print("Cropping to square")
    a = min(signal.shape[-1],signal.shape[-2])
    signal = signal [...,0:a,0:a]
    observation = observation [...,0:a,0:a]

if normGMM:
    signal = (signal - np.mean(observation)) / np.std(observation)
    observation = (observation - np.mean(observation)) / np.std(observation)

print("After normalization:")
print(f"Mean signal {np.mean(signal)}, std signal {np.std(signal)} ")
print(f"Mean observation {np.mean(observation)}, std observation {np.std(observation)} ")

print(f"\n\nConcatenated arrays:\tSignal: {signal.shape}\tObservation: {observation.shape}")

plt.figure(figsize=(10,20))
plt.subplot(1,2,1)
plt.imshow(observation[0][400:800,400:800])
plt.title("Noisy")

plt.subplot(1,2,2)
plt.imshow(signal[0][400:800,400:800])
plt.title("Clean")
# Out:
# File 15h18timelapse.tiff: shape: (52, 1392, 1392)
# File 15h55timelapse.tiff: shape: (96, 1392, 1392)
# File 16h15timelapse.tiff: shape: (176, 1392, 1392)
# File 17h05timelapse.tiff: shape: (116, 1392, 1392)
# File 17h31timelapse.tiff: shape: (55, 1392, 1392)
# File 18h25timelapse.tiff: shape: (104, 1392, 1392)
# File 19h34timelapse.tiff: shape: (212, 1392, 1392)
# File timelapse1.tiff: shape: (50, 1392, 1392)
# File timelapse10.tiff: shape: (100, 1392, 1392)
# File timelapse11.tiff: shape: (150, 1392, 1392)
# File timelapse2.tiff: shape: (50, 1392, 1392)
# File timelapse3.tiff: shape: (147, 1392, 1392)
# File timelapse4.tiff: shape: (150, 1392, 1392)
# File timelapse5.tiff: shape: (138, 1392, 1392)
# File timelapse6.tiff: shape: (180, 1392, 1392)
# File timelapse8.tiff: shape: (121, 1392, 1392)
# File timelapse9.tiff: shape: (106, 1392, 1392)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 58
#      35     print(f"File {f}: shape: {im_obs.shape}")
#      37 # full_signal = []
#      38 # full_obs = []
#      39 # if mltplNoise:
#    (...)
#      55 #     observation = np.stack(observation)
#      56 #     signal = np.stack(signal)
# ---> 58 observation = np.stack(observation)
#      60 # if signal.shape[-1] != signal.shape[-2]:
#      61 #     print("Cropping to square")
#      62 #     a = min(signal.shape[-1],signal.shape[-2])
#      63 #     signal = signal [...,0:a,0:a]
#      64 #     observation = observation [...,0:a,0:a]
#      66 if normGMM:
#      67     # signal = (signal - np.mean(observation)) / np.std(observation)
#
# File <__array_function__ internals>:200, in stack(*args, **kwargs)
#
# File c:\Users\guillaume.minet\.conda\envs\dl_monalisa_1\lib\site-packages\numpy\core\shape_base.py:464, in stack(arrays, axis, out, dtype, casting)
#     462 shapes = {arr.shape for arr in arrays}
#     463 if len(shapes) != 1:
# --> 464     raise ValueError('all input arrays must have the same shape')
#     466 result_ndim = arrays[0].ndim + 1
#     467 axis = normalize_axis_index(axis, result_ndim)
#
# ValueError: all input arrays must have the same shape

# %%
# Optional display of Noise Model with data histogram to check that it matches 
# NOTE: does not make sense for bootstrapped histogram!
n_points = 10
bins=256
minVal = np.min(signal)
maxVal =  np.max(signal)
if checkNoiseModelDisplay:
    histogram = histNoiseModel.createHistogram(bins, minVal,maxVal, observation,signal)
    signalBinIndex_list = (np.linspace(0,n_points-1,n_points)*bins//n_points).astype(int)

    for binidx in signalBinIndex_list:
        plotProbabilityDistribution(signalBinIndex=binidx, histogram=histogram[0], gaussianMixtureNoiseModel=noiseModel, min_signal=minVal, max_signal=maxVal, n_bin=bins, device=device)

# %%
# Split into train and val, define gt data if supervised

train_data = observation[:int(0.85*observation.shape[0])]
val_data= observation[int(0.85*observation.shape[0]):]
print("Shape of training images:", train_data.shape, "Shape of validation images:", val_data.shape)
if augment:
    train_data = utils.augment_data(train_data) ### Data augmentation disabled for fast training, but can be enabled
### Optional part with GT data if supervised###
# if supervised:
train_data_gt = signal[:int(0.85*observation.shape[0])]
val_data_gt = signal[int(0.85*observation.shape[0]):]
print("Shape of GT training images:", train_data.shape, "Shape of validation images:", val_data.shape)
if augment:
    train_data_gt = utils.augment_data(train_data_gt) ### Data augmentation disabled for fast training, but can be enabled
# Out:
# Shape of training images: (454, 1392, 1392) Shape of validation images: (81, 1392, 1392)
# Shape of GT training images: (454, 1392, 1392) Shape of validation images: (81, 1392, 1392)

# %%
# Patches extraction

img_width = observation.shape[2]
img_height = observation.shape[1]
num_patches = int(float(img_width*img_height)/float(patch_size**2)*1)

# if not supervised:
#     train_images = utils.extract_patches(train_data, patch_size, num_patches)
#     val_images = utils.extract_patches(val_data, patch_size, num_patches)
# else:
train_images,train_images_gt = utils.extract_patches_supervised(train_data,train_data_gt, patch_size, num_patches)
val_images,val_images_gt  = utils.extract_patches_supervised(val_data,val_data_gt, patch_size, num_patches)
    
img_shape = (train_images.shape[1], train_images.shape[2])
print("Shape of training images:", train_images.shape, "Shape of validation images:", val_images.shape)
# Out:
# 100%|██████████| 454/454 [00:06<00:00, 65.66it/s]
# 100%|██████████| 81/81 [00:02<00:00, 35.45it/s]
# Shape of training images: (214742, 64, 64) Shape of validation images: (38313, 64, 64)

# %%
# Patches selection
thresh = 0.05

# train
train_images_gt_norm = np.linalg.norm(train_images_gt,axis=(1,2))
train_images_gt_norm = train_images_gt_norm / train_images_gt_norm.max()
ind_norm = np.where(train_images_gt_norm > thresh)[0]

train_images_gt = train_images_gt[ind_norm,...]
train_images = train_images[ind_norm,...]

# val
val_images_gt_norm = np.linalg.norm(val_images_gt,axis=(1,2))
val_images_gt_norm = val_images_gt_norm / val_images_gt_norm.max()
ind_norm = np.where(val_images_gt_norm > thresh)[0]

val_images_gt = val_images_gt[ind_norm,...]
val_images = val_images[ind_norm,...]

# %%
# We limit validation patches to 1000 to speed up training but it is not necessary
val_images = val_images[:1000]
test_images = val_images[:100]
if supervised:
    val_images_gt = val_images_gt [:1000] 
    test_images_gt = val_images_gt[:100]

# %%
print("Shape of training images:", train_images.shape, "Shape of validation images:", val_images.shape)
# Out:
# Shape of training images: (32266, 64, 64) Shape of validation images: (1000, 64, 64)

# %%
# if supervised: Display of paired dataset to check that it is matching 

if supervised:
    import random
    idx = random.randrange(train_images.shape[0])

    plt.figure(figsize=(5,10))
    plt.subplot(1,2,1)
    plt.imshow(train_images[idx])

    plt.subplot(1,2,2)
    plt.imshow(train_images_gt[idx])

    idx = random.randrange(val_images.shape[0])
    plt.figure(figsize=(5,10))
    plt.subplot(1,2,1)
    plt.imshow(val_images[idx])

    plt.subplot(1,2,2)
    plt.imshow(val_images_gt[idx])

# %%
# Choose make_data_manager for supervised training or make_data_manager 2 for supervised

if upsamp>1 or supervised:
    if not supervised:
        train_images_gt = train_images.copy()
        val_images_gt = val_images.copy()
        test_images_gt = test_images.copy()

    train_loader, val_loader, test_loader, data_mean, data_std = boilerplate._make_datamanager_supervised(train_images,train_images_gt,val_images,
                                                                                            val_images_gt, test_images,test_images_gt,
                                                                                            batch_size,test_batch_size,upsamp=upsamp)

else:
    train_loader, val_loader, test_loader, data_mean, data_std = boilerplate._make_datamanager(train_images,val_images,
                                                                                            test_images,batch_size,
                                                                                            test_batch_size)


# Here we ensure that steps_per_epoch not bigger than len(train_loader)
# It never goes into validation otherwise, and so it never saves the model.
steps_per_epoch=min(len(train_loader)-1,steps_per_epoch)
print(steps_per_epoch)
# Out:
# 400

# %%
print(data_mean,data_std)
# Out:
# 1.169395411824814 2.196248609260065

# %%
# if supervised: Display of paired dataset to check that it is still matching in the loader  

if supervised or upsamp > 1:
    for batch_idx, (x, y) in enumerate(train_loader):
        print(batch_idx)

        x2 = x.cpu().numpy()
        x2 = x2[0]
        print(x2.shape)

        y2 = y.cpu().numpy()
        y2 = y2[0]

        plt.figure(figsize=(5,5))
        plt.subplot(1,2,1)
        plt.imshow(x2)
        plt.subplot(1,2,2)
        plt.imshow(y2)
        if batch_idx > 5:
            break

    batch_idx, (x, y) = next(enumerate(val_loader))

    x2 = x.cpu().numpy()
    x2 = x2[0]
    print(x2.shape)

    y2 = y.cpu().numpy()
    y2 = y2[0]

    plt.figure(figsize=(5,5))
    plt.subplot(1,2,1)
    plt.imshow(x2)
    plt.subplot(1,2,2)
    plt.imshow(y2)
# Out:
# 0
# (64, 64)
# 1
# (64, 64)
# 2
# (64, 64)
# 3
# (64, 64)
# 4
# (64, 64)
# 5
# (64, 64)
# 6
# (64, 64)
# (64, 64)

# %%
# Train network


model = LadderVAE(z_dims=z_dims,blocks_per_layer=blocks_per_layer,data_mean=data_mean,data_std=data_std,noiseModel=noiseModel,
                  device=device,batchnorm=batchnorm,free_bits=free_bits,img_shape=img_shape).cuda()

model.train() # Model set in training mode

training.train_network(model=model,lr=lr,max_epochs=max_epochs,steps_per_epoch=steps_per_epoch,directory_path=save_model_basedir,
                       train_loader=train_loader,val_loader=val_loader,test_loader=test_loader,
                       virtual_batch=virtual_batch,gaussian_noise_std=gaussian_noise_std,
                       model_name=modelName,val_loss_patience=100,beta=beta)
# Out:
# Epoch[1/500] Training Loss: 2.015 Reconstruction Loss: 2.007 KL Loss: 1.642
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 2.0786778926849365 Min validation loss: 2.0786778926849365
# Time for epoch: 554seconds
# Est remaining time: 3 days, 4:47:26 or 276446 seconds
# ----------------------------------------
# Epoch[2/500] Training Loss: 1.605 Reconstruction Loss: 1.596 KL Loss: 1.788
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 2.0369436740875244 Min validation loss: 2.0369436740875244
# Time for epoch: 547seconds
# Est remaining time: 3 days, 3:40:06 or 272406 seconds
# ----------------------------------------
# Epoch[3/500] Training Loss: 1.509 Reconstruction Loss: 1.500 KL Loss: 1.834
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 1 Validation Loss: 2.1203835010528564 Min validation loss: 2.0369436740875244
# Time for epoch: 547seconds
# Est remaining time: 3 days, 3:30:59 or 271859 seconds
# ----------------------------------------
# Epoch[4/500] Training Loss: 1.435 Reconstruction Loss: 1.426 KL Loss: 1.915
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 2 Validation Loss: 2.1768858432769775 Min validation loss: 2.0369436740875244
# Time for epoch: 548seconds
# Est remaining time: 3 days, 3:30:08 or 271808 seconds
# ----------------------------------------
# Epoch[5/500] Training Loss: 1.372 Reconstruction Loss: 1.362 KL Loss: 1.989
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 3 Validation Loss: 2.174736261367798 Min validation loss: 2.0369436740875244
# Time for epoch: 549seconds
# Est remaining time: 3 days, 3:29:15 or 271755 seconds
# ----------------------------------------
# Epoch[6/500] Training Loss: 1.319 Reconstruction Loss: 1.309 KL Loss: 2.034
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 4 Validation Loss: 2.110686779022217 Min validation loss: 2.0369436740875244
# Time for epoch: 548seconds
# Est remaining time: 3 days, 3:11:52 or 270712 seconds
# ----------------------------------------
# Epoch[7/500] Training Loss: 1.274 Reconstruction Loss: 1.264 KL Loss: 2.046
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 2.033233880996704 Min validation loss: 2.033233880996704
# Time for epoch: 545seconds
# Est remaining time: 3 days, 2:38:05 or 268685 seconds
# ----------------------------------------
# Epoch[8/500] Training Loss: 1.231 Reconstruction Loss: 1.221 KL Loss: 2.046
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.9993407726287842 Min validation loss: 1.9993407726287842
# Time for epoch: 550seconds
# Est remaining time: 3 days, 3:10:00 or 270600 seconds
# ----------------------------------------
# Epoch[9/500] Training Loss: 1.194 Reconstruction Loss: 1.184 KL Loss: 2.056
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.990563988685608 Min validation loss: 1.990563988685608
# Time for epoch: 545seconds
# Est remaining time: 3 days, 2:19:55 or 267595 seconds
# ----------------------------------------
# Epoch[10/500] Training Loss: 1.160 Reconstruction Loss: 1.150 KL Loss: 2.076
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 1 Validation Loss: 1.9943220615386963 Min validation loss: 1.990563988685608
# Time for epoch: 549seconds
# Est remaining time: 3 days, 2:43:30 or 269010 seconds
# ----------------------------------------
# Epoch[11/500] Training Loss: 1.133 Reconstruction Loss: 1.122 KL Loss: 2.097
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 2 Validation Loss: 2.007007360458374 Min validation loss: 1.990563988685608
# Time for epoch: 545seconds
# Est remaining time: 3 days, 2:01:45 or 266505 seconds
# ----------------------------------------
# Epoch[12/500] Training Loss: 1.113 Reconstruction Loss: 1.102 KL Loss: 2.117
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 3 Validation Loss: 2.020075798034668 Min validation loss: 1.990563988685608
# Time for epoch: 548seconds
# Est remaining time: 3 days, 2:17:04 or 267424 seconds
# ----------------------------------------
# Epoch[13/500] Training Loss: 1.098 Reconstruction Loss: 1.087 KL Loss: 2.125
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 4 Validation Loss: 2.023174285888672 Min validation loss: 1.990563988685608
# Time for epoch: 545seconds
# Est remaining time: 3 days, 1:43:35 or 265415 seconds
# ----------------------------------------
# Epoch[14/500] Training Loss: 1.087 Reconstruction Loss: 1.077 KL Loss: 2.122
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 5 Validation Loss: 2.038480281829834 Min validation loss: 1.990563988685608
# Time for epoch: 549seconds
# Est remaining time: 3 days, 2:06:54 or 266814 seconds
# ----------------------------------------
# Epoch[15/500] Training Loss: 1.080 Reconstruction Loss: 1.069 KL Loss: 2.111
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 6 Validation Loss: 2.039405345916748 Min validation loss: 1.990563988685608
# Time for epoch: 548seconds
# Est remaining time: 3 days, 1:49:40 or 265780 seconds
# ----------------------------------------
# Epoch[16/500] Training Loss: 1.072 Reconstruction Loss: 1.062 KL Loss: 2.090
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 7 Validation Loss: 2.0235118865966797 Min validation loss: 1.990563988685608
# Time for epoch: 545seconds
# Est remaining time: 3 days, 1:16:20 or 263780 seconds
# ----------------------------------------
# Epoch[17/500] Training Loss: 1.066 Reconstruction Loss: 1.056 KL Loss: 2.061
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 8 Validation Loss: 2.0203261375427246 Min validation loss: 1.990563988685608
# Time for epoch: 547seconds
# Est remaining time: 3 days, 1:23:21 or 264201 seconds
# ----------------------------------------
# Epoch[18/500] Training Loss: 1.061 Reconstruction Loss: 1.051 KL Loss: 2.022
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 9 Validation Loss: 1.9966766834259033 Min validation loss: 1.990563988685608
# Time for epoch: 546seconds
# Est remaining time: 3 days, 1:06:12 or 263172 seconds
# ----------------------------------------
# Epoch[19/500] Training Loss: 1.056 Reconstruction Loss: 1.046 KL Loss: 1.979
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.9764599800109863 Min validation loss: 1.9764599800109863
# Time for epoch: 548seconds
# Est remaining time: 3 days, 1:13:08 or 263588 seconds
# ----------------------------------------
# Epoch[20/500] Training Loss: 1.052 Reconstruction Loss: 1.042 KL Loss: 1.932
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.9537689685821533 Min validation loss: 1.9537689685821533
# Time for epoch: 547seconds
# Est remaining time: 3 days, 0:56:00 or 262560 seconds
# ----------------------------------------
# Epoch[21/500] Training Loss: 1.048 Reconstruction Loss: 1.039 KL Loss: 1.888
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.9416686296463013 Min validation loss: 1.9416686296463013
# Time for epoch: 550seconds
# Est remaining time: 3 days, 1:10:50 or 263450 seconds
# ----------------------------------------
# Epoch[22/500] Training Loss: 1.045 Reconstruction Loss: 1.036 KL Loss: 1.843
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.9117350578308105 Min validation loss: 1.9117350578308105
# Time for epoch: 546seconds
# Est remaining time: 3 days, 0:29:48 or 260988 seconds
# ----------------------------------------
# Epoch[23/500] Training Loss: 1.042 Reconstruction Loss: 1.033 KL Loss: 1.796
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.8910492658615112 Min validation loss: 1.8910492658615112
# Time for epoch: 548seconds
# Est remaining time: 3 days, 0:36:36 or 261396 seconds
# ----------------------------------------
# Epoch[24/500] Training Loss: 1.040 Reconstruction Loss: 1.031 KL Loss: 1.755
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.868707299232483 Min validation loss: 1.868707299232483
# Time for epoch: 547seconds
# Est remaining time: 3 days, 0:19:32 or 260372 seconds
# ----------------------------------------
# Epoch[25/500] Training Loss: 1.037 Reconstruction Loss: 1.028 KL Loss: 1.713
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.8410323858261108 Min validation loss: 1.8410323858261108
# Time for epoch: 549seconds
# Est remaining time: 3 days, 0:26:15 or 260775 seconds
# ----------------------------------------
# Epoch[26/500] Training Loss: 1.035 Reconstruction Loss: 1.027 KL Loss: 1.668
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.8233513832092285 Min validation loss: 1.8233513832092285
# Time for epoch: 547seconds
# Est remaining time: 3 days, 0:01:18 or 259278 seconds
# ----------------------------------------
# Epoch[27/500] Training Loss: 1.033 Reconstruction Loss: 1.025 KL Loss: 1.630
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.8000118732452393 Min validation loss: 1.8000118732452393
# Time for epoch: 623seconds
# Est remaining time: 3 days, 9:51:19 or 294679 seconds
# ----------------------------------------
# Epoch[28/500] Training Loss: 1.031 Reconstruction Loss: 1.023 KL Loss: 1.593
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.7847797870635986 Min validation loss: 1.7847797870635986
# Time for epoch: 851seconds
# Est remaining time: 4 days, 15:34:32 or 401672 seconds
# ----------------------------------------
# Epoch[29/500] Training Loss: 1.030 Reconstruction Loss: 1.022 KL Loss: 1.553
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.7613191604614258 Min validation loss: 1.7613191604614258
# Time for epoch: 837seconds
# Est remaining time: 4 days, 13:30:27 or 394227 seconds
# ----------------------------------------
# Epoch[30/500] Training Loss: 1.028 Reconstruction Loss: 1.021 KL Loss: 1.520
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.7434914112091064 Min validation loss: 1.7434914112091064
# Time for epoch: 839seconds
# Est remaining time: 4 days, 13:32:10 or 394330 seconds
# ----------------------------------------
# Epoch[31/500] Training Loss: 1.027 Reconstruction Loss: 1.019 KL Loss: 1.486
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.7239091396331787 Min validation loss: 1.7239091396331787
# Time for epoch: 787seconds
# Est remaining time: 4 days, 6:31:43 or 369103 seconds
# ----------------------------------------
# Epoch[32/500] Training Loss: 1.025 Reconstruction Loss: 1.018 KL Loss: 1.453
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.7124476432800293 Min validation loss: 1.7124476432800293
# Time for epoch: 551seconds
# Est remaining time: 2 days, 23:37:48 or 257868 seconds
# ----------------------------------------
# Epoch[33/500] Training Loss: 1.024 Reconstruction Loss: 1.017 KL Loss: 1.423
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.7023264169692993 Min validation loss: 1.7023264169692993
# Time for epoch: 550seconds
# Est remaining time: 2 days, 23:20:50 or 256850 seconds
# ----------------------------------------
# Epoch[34/500] Training Loss: 1.023 Reconstruction Loss: 1.016 KL Loss: 1.395
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.6852617263793945 Min validation loss: 1.6852617263793945
# Time for epoch: 551seconds
# Est remaining time: 2 days, 23:19:26 or 256766 seconds
# ----------------------------------------
# Epoch[35/500] Training Loss: 1.022 Reconstruction Loss: 1.015 KL Loss: 1.371
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.6788504123687744 Min validation loss: 1.6788504123687744
# Time for epoch: 548seconds
# Est remaining time: 2 days, 22:47:00 or 254820 seconds
# ----------------------------------------
# Epoch[36/500] Training Loss: 1.021 Reconstruction Loss: 1.014 KL Loss: 1.345
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.656158447265625 Min validation loss: 1.656158447265625
# Time for epoch: 552seconds
# Est remaining time: 2 days, 23:08:48 or 256128 seconds
# ----------------------------------------
# Epoch[37/500] Training Loss: 1.020 Reconstruction Loss: 1.013 KL Loss: 1.319
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.6457382440567017 Min validation loss: 1.6457382440567017
# Time for epoch: 548seconds
# Est remaining time: 2 days, 22:28:44 or 253724 seconds
# ----------------------------------------
# Epoch[38/500] Training Loss: 1.019 Reconstruction Loss: 1.012 KL Loss: 1.297
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.6310601234436035 Min validation loss: 1.6310601234436035
# Time for epoch: 550seconds
# Est remaining time: 2 days, 22:35:00 or 254100 seconds
# ----------------------------------------
# Epoch[39/500] Training Loss: 1.018 Reconstruction Loss: 1.011 KL Loss: 1.274
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.6266658306121826 Min validation loss: 1.6266658306121826
# Time for epoch: 548seconds
# Est remaining time: 2 days, 22:10:28 or 252628 seconds
# ----------------------------------------
# Epoch[40/500] Training Loss: 1.017 Reconstruction Loss: 1.011 KL Loss: 1.254
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.6214663982391357 Min validation loss: 1.6214663982391357
# Time for epoch: 550seconds
# Est remaining time: 2 days, 22:16:40 or 253000 seconds
# ----------------------------------------
# Epoch[41/500] Training Loss: 1.016 Reconstruction Loss: 1.010 KL Loss: 1.236
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.605688214302063 Min validation loss: 1.605688214302063
# Time for epoch: 550seconds
# Est remaining time: 2 days, 22:07:30 or 252450 seconds
# ----------------------------------------
# Epoch[42/500] Training Loss: 1.015 Reconstruction Loss: 1.009 KL Loss: 1.216
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.5957776308059692 Min validation loss: 1.5957776308059692
# Time for epoch: 548seconds
# Est remaining time: 2 days, 21:43:04 or 250984 seconds
# ----------------------------------------
# Epoch[43/500] Training Loss: 1.015 Reconstruction Loss: 1.009 KL Loss: 1.198
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.5900907516479492 Min validation loss: 1.5900907516479492
# Time for epoch: 549seconds
# Est remaining time: 2 days, 21:41:33 or 250893 seconds
# ----------------------------------------
# Epoch[44/500] Training Loss: 1.014 Reconstruction Loss: 1.008 KL Loss: 1.182
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.5891897678375244 Min validation loss: 1.5891897678375244
# Time for epoch: 550seconds
# Est remaining time: 2 days, 21:40:00 or 250800 seconds
# ----------------------------------------
# Epoch[45/500] Training Loss: 1.013 Reconstruction Loss: 1.007 KL Loss: 1.168
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.5760282278060913 Min validation loss: 1.5760282278060913
# Time for epoch: 549seconds
# Est remaining time: 2 days, 21:23:15 or 249795 seconds
# ----------------------------------------
# Epoch[46/500] Training Loss: 1.013 Reconstruction Loss: 1.007 KL Loss: 1.153
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.572693109512329 Min validation loss: 1.572693109512329
# Time for epoch: 551seconds
# Est remaining time: 2 days, 21:29:14 or 250154 seconds
# ----------------------------------------
# Epoch[47/500] Training Loss: 1.012 Reconstruction Loss: 1.006 KL Loss: 1.140
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.564454197883606 Min validation loss: 1.564454197883606
# Time for epoch: 552seconds
# Est remaining time: 2 days, 21:27:36 or 250056 seconds
# ----------------------------------------
# Epoch[48/500] Training Loss: 1.011 Reconstruction Loss: 1.006 KL Loss: 1.126
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.5606606006622314 Min validation loss: 1.5606606006622314
# Time for epoch: 552seconds
# Est remaining time: 2 days, 21:18:24 or 249504 seconds
# ----------------------------------------
# Epoch[49/500] Training Loss: 1.011 Reconstruction Loss: 1.005 KL Loss: 1.115
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.5569322109222412 Min validation loss: 1.5569322109222412
# Time for epoch: 553seconds
# Est remaining time: 2 days, 21:16:43 or 249403 seconds
# ----------------------------------------
# Epoch[50/500] Training Loss: 1.010 Reconstruction Loss: 1.005 KL Loss: 1.103
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.554267406463623 Min validation loss: 1.554267406463623
# Time for epoch: 553seconds
# Est remaining time: 2 days, 21:07:30 or 248850 seconds
# ----------------------------------------
# Epoch[51/500] Training Loss: 1.010 Reconstruction Loss: 1.004 KL Loss: 1.092
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.5421555042266846 Min validation loss: 1.5421555042266846
# Time for epoch: 556seconds
# Est remaining time: 2 days, 21:20:44 or 249644 seconds
# ----------------------------------------
# Epoch[52/500] Training Loss: 1.009 Reconstruction Loss: 1.004 KL Loss: 1.081
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.539654016494751 Min validation loss: 1.539654016494751
# Time for epoch: 552seconds
# Est remaining time: 2 days, 20:41:36 or 247296 seconds
# ----------------------------------------
# Epoch[53/500] Training Loss: 1.009 Reconstruction Loss: 1.003 KL Loss: 1.070
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.5354173183441162 Min validation loss: 1.5354173183441162
# Time for epoch: 553seconds
# Est remaining time: 2 days, 20:39:51 or 247191 seconds
# ----------------------------------------
# Epoch[54/500] Training Loss: 1.008 Reconstruction Loss: 1.003 KL Loss: 1.062
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.5317167043685913 Min validation loss: 1.5317167043685913
# Time for epoch: 549seconds
# Est remaining time: 2 days, 20:00:54 or 244854 seconds
# ----------------------------------------
# Epoch[55/500] Training Loss: 1.008 Reconstruction Loss: 1.003 KL Loss: 1.054
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.530400276184082 Min validation loss: 1.530400276184082
# Time for epoch: 553seconds
# Est remaining time: 2 days, 20:21:25 or 246085 seconds
# ----------------------------------------
# Epoch[56/500] Training Loss: 1.008 Reconstruction Loss: 1.002 KL Loss: 1.045
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.5288035869598389 Min validation loss: 1.5288035869598389
# Time for epoch: 552seconds
# Est remaining time: 2 days, 20:04:48 or 245088 seconds
# ----------------------------------------
# Epoch[57/500] Training Loss: 1.007 Reconstruction Loss: 1.002 KL Loss: 1.038
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.52223539352417 Min validation loss: 1.52223539352417
# Time for epoch: 555seconds
# Est remaining time: 2 days, 20:17:45 or 245865 seconds
# ----------------------------------------
# Epoch[58/500] Training Loss: 1.007 Reconstruction Loss: 1.002 KL Loss: 1.030
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 1 Validation Loss: 1.5239989757537842 Min validation loss: 1.52223539352417
# Time for epoch: 551seconds
# Est remaining time: 2 days, 19:39:02 or 243542 seconds
# ----------------------------------------
# Epoch[59/500] Training Loss: 1.007 Reconstruction Loss: 1.001 KL Loss: 1.023
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.5159835815429688 Min validation loss: 1.5159835815429688
# Time for epoch: 553seconds
# Est remaining time: 2 days, 19:44:33 or 243873 seconds
# ----------------------------------------
# Epoch[60/500] Training Loss: 1.006 Reconstruction Loss: 1.001 KL Loss: 1.015
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.513800859451294 Min validation loss: 1.513800859451294
# Time for epoch: 552seconds
# Est remaining time: 2 days, 19:28:00 or 242880 seconds
# ----------------------------------------
# Epoch[61/500] Training Loss: 1.006 Reconstruction Loss: 1.001 KL Loss: 1.009
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.512986183166504 Min validation loss: 1.512986183166504
# Time for epoch: 552seconds
# Est remaining time: 2 days, 19:18:48 or 242328 seconds
# ----------------------------------------
# Epoch[62/500] Training Loss: 1.005 Reconstruction Loss: 1.000 KL Loss: 1.002
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.5111684799194336 Min validation loss: 1.5111684799194336
# Time for epoch: 549seconds
# Est remaining time: 2 days, 18:47:42 or 240462 seconds
# ----------------------------------------
# Epoch[63/500] Training Loss: 1.005 Reconstruction Loss: 1.000 KL Loss: 0.997
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.5074679851531982 Min validation loss: 1.5074679851531982
# Time for epoch: 553seconds
# Est remaining time: 2 days, 19:07:41 or 241661 seconds
# ----------------------------------------
# Epoch[64/500] Training Loss: 1.005 Reconstruction Loss: 1.000 KL Loss: 0.992
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 1 Validation Loss: 1.5081510543823242 Min validation loss: 1.5074679851531982
# Time for epoch: 553seconds
# Est remaining time: 2 days, 18:58:28 or 241108 seconds
# ----------------------------------------
# Epoch[65/500] Training Loss: 1.004 Reconstruction Loss: 0.999 KL Loss: 0.985
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.5023829936981201 Min validation loss: 1.5023829936981201
# Time for epoch: 551seconds
# Est remaining time: 2 days, 18:34:45 or 239685 seconds
# ----------------------------------------
# Epoch[66/500] Training Loss: 1.004 Reconstruction Loss: 0.999 KL Loss: 0.981
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4994421005249023 Min validation loss: 1.4994421005249023
# Time for epoch: 553seconds
# Est remaining time: 2 days, 18:40:02 or 240002 seconds
# ----------------------------------------
# Epoch[67/500] Training Loss: 1.004 Reconstruction Loss: 0.999 KL Loss: 0.977
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.496575117111206 Min validation loss: 1.496575117111206
# Time for epoch: 549seconds
# Est remaining time: 2 days, 18:01:57 or 237717 seconds
# ----------------------------------------
# Epoch[68/500] Training Loss: 1.003 Reconstruction Loss: 0.999 KL Loss: 0.971
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.494365930557251 Min validation loss: 1.494365930557251
# Time for epoch: 553seconds
# Est remaining time: 2 days, 18:21:36 or 238896 seconds
# ----------------------------------------
# Epoch[69/500] Training Loss: 1.003 Reconstruction Loss: 0.998 KL Loss: 0.966
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4933888912200928 Min validation loss: 1.4933888912200928
# Time for epoch: 550seconds
# Est remaining time: 2 days, 17:50:50 or 237050 seconds
# ----------------------------------------
# Epoch[70/500] Training Loss: 1.003 Reconstruction Loss: 0.998 KL Loss: 0.961
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 1 Validation Loss: 1.4942556619644165 Min validation loss: 1.4933888912200928
# Time for epoch: 552seconds
# Est remaining time: 2 days, 17:56:00 or 237360 seconds
# ----------------------------------------
# Epoch[71/500] Training Loss: 1.003 Reconstruction Loss: 0.998 KL Loss: 0.959
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4890414476394653 Min validation loss: 1.4890414476394653
# Time for epoch: 549seconds
# Est remaining time: 2 days, 17:25:21 or 235521 seconds
# ----------------------------------------
# Epoch[72/500] Training Loss: 1.003 Reconstruction Loss: 0.998 KL Loss: 0.952
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4881494045257568 Min validation loss: 1.4881494045257568
# Time for epoch: 551seconds
# Est remaining time: 2 days, 17:30:28 or 235828 seconds
# ----------------------------------------
# Epoch[73/500] Training Loss: 1.002 Reconstruction Loss: 0.997 KL Loss: 0.949
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4860057830810547 Min validation loss: 1.4860057830810547
# Time for epoch: 552seconds
# Est remaining time: 2 days, 17:28:24 or 235704 seconds
# ----------------------------------------
# Epoch[74/500] Training Loss: 1.002 Reconstruction Loss: 0.997 KL Loss: 0.943
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4829072952270508 Min validation loss: 1.4829072952270508
# Time for epoch: 551seconds
# Est remaining time: 2 days, 17:12:06 or 234726 seconds
# ----------------------------------------
# Epoch[75/500] Training Loss: 1.002 Reconstruction Loss: 0.997 KL Loss: 0.940
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 1 Validation Loss: 1.486351728439331 Min validation loss: 1.4829072952270508
# Time for epoch: 549seconds
# Est remaining time: 2 days, 16:48:45 or 233325 seconds
# ----------------------------------------
# Epoch[76/500] Training Loss: 1.002 Reconstruction Loss: 0.997 KL Loss: 0.936
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4822022914886475 Min validation loss: 1.4822022914886475
# Time for epoch: 552seconds
# Est remaining time: 2 days, 17:00:48 or 234048 seconds
# ----------------------------------------
# Epoch[77/500] Training Loss: 1.001 Reconstruction Loss: 0.997 KL Loss: 0.933
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4805970191955566 Min validation loss: 1.4805970191955566
# Time for epoch: 552seconds
# Est remaining time: 2 days, 16:51:36 or 233496 seconds
# ----------------------------------------
# Epoch[78/500] Training Loss: 1.001 Reconstruction Loss: 0.996 KL Loss: 0.928
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4803879261016846 Min validation loss: 1.4803879261016846
# Time for epoch: 553seconds
# Est remaining time: 2 days, 16:49:26 or 233366 seconds
# ----------------------------------------
# Epoch[79/500] Training Loss: 1.001 Reconstruction Loss: 0.996 KL Loss: 0.924
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.478129506111145 Min validation loss: 1.478129506111145
# Time for epoch: 552seconds
# Est remaining time: 2 days, 16:33:12 or 232392 seconds
# ----------------------------------------
# Epoch[80/500] Training Loss: 1.001 Reconstruction Loss: 0.996 KL Loss: 0.921
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4746570587158203 Min validation loss: 1.4746570587158203
# Time for epoch: 549seconds
# Est remaining time: 2 days, 16:03:00 or 230580 seconds
# ----------------------------------------
# Epoch[81/500] Training Loss: 1.000 Reconstruction Loss: 0.996 KL Loss: 0.918
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 1 Validation Loss: 1.4757033586502075 Min validation loss: 1.4746570587158203
# Time for epoch: 552seconds
# Est remaining time: 2 days, 16:14:48 or 231288 seconds
# ----------------------------------------
# Epoch[82/500] Training Loss: 1.000 Reconstruction Loss: 0.996 KL Loss: 0.914
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 2 Validation Loss: 1.4789305925369263 Min validation loss: 1.4746570587158203
# Time for epoch: 552seconds
# Est remaining time: 2 days, 16:05:36 or 230736 seconds
# ----------------------------------------
# Epoch[83/500] Training Loss: 1.000 Reconstruction Loss: 0.996 KL Loss: 0.910
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4719444513320923 Min validation loss: 1.4719444513320923
# Time for epoch: 554seconds
# Est remaining time: 2 days, 16:10:18 or 231018 seconds
# ----------------------------------------
# Epoch[84/500] Training Loss: 1.000 Reconstruction Loss: 0.995 KL Loss: 0.907
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4708784818649292 Min validation loss: 1.4708784818649292
# Time for epoch: 550seconds
# Est remaining time: 2 days, 15:33:20 or 228800 seconds
# ----------------------------------------
# Epoch[85/500] Training Loss: 1.000 Reconstruction Loss: 0.995 KL Loss: 0.903
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4683696031570435 Min validation loss: 1.4683696031570435
# Time for epoch: 554seconds
# Est remaining time: 2 days, 15:51:50 or 229910 seconds
# ----------------------------------------
# Epoch[86/500] Training Loss: 1.000 Reconstruction Loss: 0.995 KL Loss: 0.900
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4639500379562378 Min validation loss: 1.4639500379562378
# Time for epoch: 554seconds
# Est remaining time: 2 days, 15:42:36 or 229356 seconds
# ----------------------------------------
# Epoch[87/500] Training Loss: 0.999 Reconstruction Loss: 0.995 KL Loss: 0.896
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4638445377349854 Min validation loss: 1.4638445377349854
# Time for epoch: 554seconds
# Est remaining time: 2 days, 15:33:22 or 228802 seconds
# ----------------------------------------
# Epoch[88/500] Training Loss: 0.999 Reconstruction Loss: 0.995 KL Loss: 0.893
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 1 Validation Loss: 1.4662076234817505 Min validation loss: 1.4638445377349854
# Time for epoch: 551seconds
# Est remaining time: 2 days, 15:03:32 or 227012 seconds
# ----------------------------------------
# Epoch[89/500] Training Loss: 0.999 Reconstruction Loss: 0.995 KL Loss: 0.890
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4598480463027954 Min validation loss: 1.4598480463027954
# Time for epoch: 554seconds
# Est remaining time: 2 days, 15:14:54 or 227694 seconds
# ----------------------------------------
# ...
# Time for epoch: 549seconds
# Est remaining time: 2 days, 5:40:48 or 193248 seconds
# ----------------------------------------
# Epoch[149/500] Training Loss: 0.993 Reconstruction Loss: 0.989 KL Loss: 0.762
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4149069786071777 Min validation loss: 1.4149069786071777
# Time for epoch: 552seconds
# Est remaining time: 2 days, 5:49:12 or 193752 seconds
# ----------------------------------------
# Epoch[150/500] Training Loss: 0.993 Reconstruction Loss: 0.989 KL Loss: 0.761
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4133188724517822 Min validation loss: 1.4133188724517822
# Time for epoch: 548seconds
# Est remaining time: 2 days, 5:16:40 or 191800 seconds
# ----------------------------------------
# Epoch[151/500] Training Loss: 0.992 Reconstruction Loss: 0.989 KL Loss: 0.759
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 1 Validation Loss: 1.4144465923309326 Min validation loss: 1.4133188724517822
# Time for epoch: 550seconds
# Est remaining time: 2 days, 5:19:10 or 191950 seconds
# ----------------------------------------
# Epoch[152/500] Training Loss: 0.992 Reconstruction Loss: 0.989 KL Loss: 0.758
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.413087248802185 Min validation loss: 1.413087248802185
# Time for epoch: 549seconds
# Est remaining time: 2 days, 5:04:12 or 191052 seconds
# ----------------------------------------
# Epoch[153/500] Training Loss: 0.992 Reconstruction Loss: 0.989 KL Loss: 0.758
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 1 Validation Loss: 1.413771390914917 Min validation loss: 1.413087248802185
# Time for epoch: 552seconds
# Est remaining time: 2 days, 5:12:24 or 191544 seconds
# ----------------------------------------
# Epoch[154/500] Training Loss: 0.992 Reconstruction Loss: 0.989 KL Loss: 0.756
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4118614196777344 Min validation loss: 1.4118614196777344
# Time for epoch: 550seconds
# Est remaining time: 2 days, 4:51:40 or 190300 seconds
# ----------------------------------------
# Epoch[155/500] Training Loss: 0.992 Reconstruction Loss: 0.988 KL Loss: 0.755
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4115562438964844 Min validation loss: 1.4115562438964844
# Time for epoch: 550seconds
# Est remaining time: 2 days, 4:42:30 or 189750 seconds
# ----------------------------------------
# Epoch[156/500] Training Loss: 0.992 Reconstruction Loss: 0.988 KL Loss: 0.754
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 1 Validation Loss: 1.412415623664856 Min validation loss: 1.4115562438964844
# Time for epoch: 550seconds
# Est remaining time: 2 days, 4:33:20 or 189200 seconds
# ----------------------------------------
# Epoch[157/500] Training Loss: 0.992 Reconstruction Loss: 0.988 KL Loss: 0.753
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 2 Validation Loss: 1.4134411811828613 Min validation loss: 1.4115562438964844
# Time for epoch: 549seconds
# Est remaining time: 2 days, 4:18:27 or 188307 seconds
# ----------------------------------------
# Epoch[158/500] Training Loss: 0.992 Reconstruction Loss: 0.988 KL Loss: 0.752
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 3 Validation Loss: 1.412272572517395 Min validation loss: 1.4115562438964844
# Time for epoch: 549seconds
# Est remaining time: 2 days, 4:09:18 or 187758 seconds
# ----------------------------------------
# Epoch[159/500] Training Loss: 0.992 Reconstruction Loss: 0.988 KL Loss: 0.751
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4103832244873047 Min validation loss: 1.4103832244873047
# Time for epoch: 550seconds
# Est remaining time: 2 days, 4:05:50 or 187550 seconds
# ----------------------------------------
# Epoch[160/500] Training Loss: 0.992 Reconstruction Loss: 0.988 KL Loss: 0.749
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4101253747940063 Min validation loss: 1.4101253747940063
# Time for epoch: 550seconds
# Est remaining time: 2 days, 3:56:40 or 187000 seconds
# ----------------------------------------
# Epoch[161/500] Training Loss: 0.992 Reconstruction Loss: 0.988 KL Loss: 0.749
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 1 Validation Loss: 1.410508155822754 Min validation loss: 1.4101253747940063
# Time for epoch: 548seconds
# Est remaining time: 2 days, 3:36:12 or 185772 seconds
# ----------------------------------------
# Epoch[162/500] Training Loss: 0.992 Reconstruction Loss: 0.988 KL Loss: 0.748
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 2 Validation Loss: 1.4108219146728516 Min validation loss: 1.4101253747940063
# Time for epoch: 550seconds
# Est remaining time: 2 days, 3:38:20 or 185900 seconds
# ----------------------------------------
# Epoch[163/500] Training Loss: 0.992 Reconstruction Loss: 0.988 KL Loss: 0.747
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 3 Validation Loss: 1.4112499952316284 Min validation loss: 1.4101253747940063
# Time for epoch: 547seconds
# Est remaining time: 2 days, 3:12:19 or 184339 seconds
# ----------------------------------------
# Epoch[164/500] Training Loss: 0.992 Reconstruction Loss: 0.988 KL Loss: 0.746
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4084093570709229 Min validation loss: 1.4084093570709229
# Time for epoch: 551seconds
# Est remaining time: 2 days, 3:25:36 or 185136 seconds
# ----------------------------------------
# Epoch[165/500] Training Loss: 0.992 Reconstruction Loss: 0.988 KL Loss: 0.745
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 1 Validation Loss: 1.4090594053268433 Min validation loss: 1.4084093570709229
# Time for epoch: 548seconds
# Est remaining time: 2 days, 2:59:40 or 183580 seconds
# ----------------------------------------
# Epoch[166/500] Training Loss: 0.992 Reconstruction Loss: 0.988 KL Loss: 0.743
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.4073066711425781 Min validation loss: 1.4073066711425781
# Time for epoch: 550seconds
# Est remaining time: 2 days, 3:01:40 or 183700 seconds
# ----------------------------------------
# Epoch[167/500] Training Loss: 0.992 Reconstruction Loss: 0.988 KL Loss: 0.743
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# Patience: 1 Validation Loss: 1.408454179763794 Min validation loss: 1.4073066711425781
# Time for epoch: 553seconds
# Est remaining time: 2 days, 3:09:09 or 184149 seconds
# ----------------------------------------
# Epoch[168/500] Training Loss: 0.991 Reconstruction Loss: 0.988 KL Loss: 0.742
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_last_vae.net
# saving ./Trained_model/model/Actin_fixed_mltplSNR_30nm_2_Noiseall_GMMall_Clip-3_5Lat_8Blocks_betaKL0.005_SupervisedAVG_NoAugment_best_vae.net
# Patience: 0 Validation Loss: 1.406118631362915 Min validation loss: 1.406118631362915
# Time for epoch: 552seconds
# Est remaining time: 2 days, 2:54:24 or 183264 seconds
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 9
#       4 model = LadderVAE(z_dims=z_dims,blocks_per_layer=blocks_per_layer,data_mean=data_mean,data_std=data_std,noiseModel=noiseModel,
#       5                   device=device,batchnorm=batchnorm,free_bits=free_bits,img_shape=img_shape).cuda()
#       7 model.train() # Model set in training mode
# ----> 9 training.train_network(model=model,lr=lr,max_epochs=max_epochs,steps_per_epoch=steps_per_epoch,directory_path=save_model_basedir,
#      10                        train_loader=train_loader,val_loader=val_loader,test_loader=test_loader,
#      11                        virtual_batch=virtual_batch,gaussian_noise_std=gaussian_noise_std,
#      12                        model_name=modelName,val_loss_patience=100,beta=beta)
#
# File c:\Users\guillaume.minet\Documents\GitHub\HDN_tests\MyScripts\..\training.py:133, in train_network(model, lr, max_epochs, steps_per_epoch, train_loader, val_loader, test_loader, virtual_batch, gaussian_noise_std, model_name, test_log_every, directory_path, val_loss_patience, nrows, max_grad_norm, beta)
#     131 else:
#     132     batch_y = virtual_batches_y [i]
# --> 133 outputs = boilerplate.forward_pass(batch_x, batch_y, device, model,
#     134                                                 gaussian_noise_std)
#     136 recons_loss = outputs['recons_loss']
#     137 kl_loss = outputs['kl_loss']
#
# File c:\Users\guillaume.minet\Documents\GitHub\HDN_tests\MyScripts\..\boilerplate\boilerplate.py:184, in forward_pass(x, y, device, model, gaussian_noise_std)
#     182 if y is not None:
#     183     y = y.to(device, non_blocking=True)
# --> 184     model_out = model(x,y)
#     185 else:
#     186     model_out = model(x)
#
# File c:\Users\guillaume.minet\.conda\envs\dl_monalisa_1\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\guillaume.minet\Documents\GitHub\HDN_tests\MyScripts\..\models\lvae.py:223, in LadderVAE.forward(self, x, y)
#     221 # Log likelihood and other info (per data point)
#     222 if self.mode_pred is False and y is not None:
# --> 223     ll, likelihood_info = self.likelihood(out,y)
#     224 else:
#     225     ll, likelihood_info = self.likelihood(out, x)
#
# File c:\Users\guillaume.minet\.conda\envs\dl_monalisa_1\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\guillaume.minet\Documents\GitHub\HDN_tests\MyScripts\..\lib\likelihoods.py:37, in LikelihoodModule.forward(self, input_, x)
#      35     ll = None
#      36 else:
# ---> 37     ll = self.log_likelihood(x, distr_params)
#      38 dct = {
#      39     'mean': mean,
#      40     'mode': mode,
#      41     'sample': sample,
#      42     'params': distr_params,
#      43 }
#      44 return ll, dct
#
# File c:\Users\guillaume.minet\Documents\GitHub\HDN_tests\MyScripts\..\lib\likelihoods.py:95, in NoiseModelLikelihood.log_likelihood(self, x, params)
#      92 x_cloned = x_cloned.permute(1,0,2,3)
#      93 x_reduced = x_cloned[0,...]
# ---> 95 likelihoods=self.noiseModel.likelihood(x_reduced,predicted_s_reduced)
#      96 logprob=torch.log(likelihoods)
#      97 return logprob
#
# File c:\Users\guillaume.minet\Documents\GitHub\HDN_tests\MyScripts\..\lib\gaussianMixtureNoiseModel.py:154, in GaussianMixtureNoiseModel.likelihood(self, observations, signals)
#     139 def likelihood(self, observations, signals):
#     140     """Evaluates the likelihood of observations given the signals and the corresponding gaussian parameters.
#     141
#     142             Parameters
#    (...)
#     152
#     153     """
# --> 154     gaussianParameters=self.getGaussianParameters(signals)
#     155     p=0
#     156     for gaussian in range(self.n_gaussian):
#
# File c:\Users\guillaume.minet\Documents\GitHub\HDN_tests\MyScripts\..\lib\gaussianMixtureNoiseModel.py:180, in GaussianMixtureNoiseModel.getGaussianParameters(self, signals)
#     178 kernels = self.weight.shape[0]//3
#     179 for num in range(kernels):
# --> 180     mu.append(self.polynomialRegressor(self.weight[num, :], signals))
#     182     sigmaTemp=self.polynomialRegressor(torch.exp(self.weight[kernels+num, :]), signals)
#     183     sigmaTemp = torch.clamp(sigmaTemp, min = self.min_sigma)
#
# File c:\Users\guillaume.minet\Documents\GitHub\HDN_tests\MyScripts\..\lib\gaussianMixtureNoiseModel.py:111, in GaussianMixtureNoiseModel.polynomialRegressor(self, weightParams, signals)
#     108 value=0
#     110 for i in range(weightParams.shape[0]):
# --> 111     value += weightParams[i] * (((signals - self.min_signal) / (self.max_signal - self.min_signal)) ** i);
#     112 return value
#
# KeyboardInterrupt:

# %% [markdown]
# # Plotting losses

# %%
directory_path = "./Trained_model/" 
trainHist=np.load(directory_path+"model/train_loss.npy")
reconHist=np.load(directory_path+"model/train_reco_loss.npy")
klHist=np.load(directory_path+"model/train_kl_loss.npy")
valHist=np.load(directory_path+"model/val_loss.npy")

# %%
plt.figure(figsize=(18, 3))
plt.subplot(1,3,1)
plt.plot(trainHist,label='training')
plt.plot(valHist,label='validation')
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend()

plt.subplot(1,3,2)
plt.plot(reconHist,label='training')
plt.xlabel("epochs")
plt.ylabel("reconstruction loss")
plt.legend()

plt.subplot(1,3,3)
plt.plot(klHist,label='training')
plt.xlabel("epochs")
plt.ylabel("KL loss")
plt.legend()
plt.show()
